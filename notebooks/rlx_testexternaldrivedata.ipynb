# %%
import cccmaNC as cnc
import loadCanESM2rlxdata as lrlx

# %matplotlib inline

cnc=reload(cnc)
lrlx=reload(lrlx)

timepers,timesels = lrlx.get_timeinfo()

#basepath='/Volumes/Kelly Data Disk 1/work/DATA/CanESM2/'
basepath='/Users/kelly/CCCma/CanSISE/DATA/CanESM2/'
casename='prei2xco2iceb'
field='st'
timeper=timepers[casename]
timesel=timesels[casename]

print type(timesel)

fname = basepath+casename+'/ts/'+casename+'_'+field+'_'+timeper+'_ts.nc'

fld = cnc.getNCvar(fname,field.upper(),timesel="3022-01-01,3121-12-31")
lat = cnc.getNCvar(fname,'lat')
lon = cnc.getNCvar(fname,'lon')
# Out:
# <type 'str'>
# Could not import data from file '/var/folders/1l/j_fm0l690q5c0995w1f7w8zm0000gn/T/cdoPy4Ur7iT'
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-14-acf0bafa1a29> in <module>()
#      20 fname = basepath+casename+'/ts/'+casename+'_'+field+'_'+timeper+'_ts.nc'
#      21
# ---> 22 fld = cnc.getNCvar(fname,field.upper(),timesel="3022-01-01,3121-12-31")
#      23 lat = cnc.getNCvar(fname,'lat')
#      24 lon = cnc.getNCvar(fname,'lon')
#
# /Users/kelly/pyscripts/classes/cccmaNC.pyc in getNCvar(filename, field, timesel, levsel, monsel, seas, calc, remlon, sqz, att)
#     226                                   returnMaArray = field))
#     227             else: # levsel and monsel are both None
# --> 228                 fld = np.squeeze(cdo.seldate(timesel,input = filename, returnMaArray = field))
#     229
# ...

# %%
import cccmautils as cutl
import cccmaplots as cplt

flddjf = cutl.seasonalize(fld,'DJF').mean(axis=0)
print flddjf.shape
# Out:
# (64, 129)

# %%
ret = cplt.kemmap(flddjf,lat,lon)

# %%
import cdo as cdo


cdo.
