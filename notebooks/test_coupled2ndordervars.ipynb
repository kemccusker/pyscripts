# %%
import cccmautils as cutl
import constants as con
# %matplotlib inline

basepath='/home/rkm/work/DATA/CanESM2/kt131f/ts/'
Cp=1004 # specific heat at const pressure (J/K/kg)
Lv=2.5e6 # specific heat of condensation (latent heat of vapo) at 0C(?@@) (J/kg)

field='MLT'


# J = kg m2/s2   --> J/kg = m2/s2

fname=basepath + 'kt131f_meridional_sens_heat_flux_2921-2931_ts.nc'; conv=Cp
#     meridional_sens_heat_flux: # m/s * C (mult by Cp to get (m/s)(J/kg)
#fname=basepath + 'kt131f_zonal_sens_heat_flux_2921-2931_ts.nc'; conv=Cp 
#     zonal_sens_heat_flux: # m/s * C (mult by Cp to get (m/s)(J/kg)
#fname=basepath + 'kt131f_meridional_latent_heat_flux_2921-2931_ts.nc'; conv=Lv
#     meridional_latent_heat_flux: m/s * kg/kg (mult by Lv to get (m/s)(J/kg))
#fname=basepath + 'kt131f_meridional_potential_energy_flux_2921-2931_ts.nc'; conv=1 # z is already mult by gravity
#     meridional_potential_energy_flux: m/s * (m2/s2) ---> m/s * (J/kg)
#     geopotential is the gravitational potential energy per unit mass at that elevation h
#     the field 'gz', or PHI, is geopotential height * gravity, which is geopotential. 
#     Z = PHI/g0, where Z is geopotential height and g0 is standard gravity. 
#     https://en.wikipedia.org/wiki/Geopotential_height
#fname=basepath + 'kt131f_meridional_flux_zonal_mom_2921-2931_ts.nc'; conv=0.5 # .5 for kinetic energy
#     meridional_flux_zonal_mom: m/s * (m2/s2) --> KE is 1/2 mv^2 which is kg m2/s2.
#       so what we have is KE per kg. ---> m/s * (J/kg)

#fname=basepath + 'kt131f_zonal_flux_zonal_mom_2921-2931_ts.nc'; conv=1; field='U' # @@?
#     zonal_flux_zonal_mom: m/s * (m2/s2) ---> m/s *(J/kg) #Not sure about a conversion?
#   @@@ note that zonal_flux_zonal_mom is incorrect for kt131f. the variable is actually just U*U.




cmin=-750; cmax=750 # mer SH flux not mult by Cp
#cmin=-.8e4; cmax=.8e4 # zon SH flux not mult by Cp
#cmin=-.015; cmax=0.015 # mer LH flux not mult by Lv
#cmin=-1e5; cmax=1e5 # mer potential energy flux
#cmin=-4000; cmax=4000 # mer flux zon mom not mult by 0.5

fld=cnc.getNCvar(fname,field,timesel='2922-01-01,2931-12-31')*conv
cmin=cmin*conv; cmax=cmax*conv

lat=cnc.getNCvar(fname,'lat')
lon=cnc.getNCvar(fname,'lon')
lev=cnc.getNCvar(fname,'plev')

print fld.shape
fldtm=fld.mean(axis=0)
print fldtm.shape

fldtmzm = fldtm.mean(axis=2)
fldzm = fld.mean(axis=3)
print fldzm.shape
print fldtmzm.shape

cplt=reload(cplt)

plt.figure()
plt.pcolor(lat,lev,fldtmzm)
ax=plt.gca()
ax.set_yscale('log')
ax.invert_yaxis()
plt.colorbar()

fig,axs=plt.subplots(1,1)
cplt.vert_plot(fldtmzm,lev,lat,axis=axs,cmin=cmin,cmax=cmax,levlim=100)
# Out:
# (120, 22, 64, 129)
# (22, 64, 129)
# (120, 22, 64)
# (22, 64)
# <matplotlib.contour.QuadContourSet instance at 0x2afbc0763128>

# %%
cplt=reload(cplt)

# no clims or contour levels
plt.figure();
fig = cplt.plotvert_allseas(fldzm,lev,lat)

# %%
plt.figure();
fig=cplt.plotvert_allseas(fldzm,lev,lat,cmin=cmin,cmax=cmax,levlim=100,latlim=0,type='nh')    

print cmax
# Out:
# 753000

# %%
# calc the vertical integral of poleward energy transport across 
#    a latitude (or all?) in units of Watts
# = 1/g int_pbot_to_ptop[  int_latcircle[ E*v a coslat dlon dp]]. a is Earth's radius

domonth=True # otherwise do season
sea='ANN'
mo=1

if domonth:
    seasonalizedt={'mo':mo}
else:
    seasonalizedt={'sea':sea}


# 1. sum around lat circle. mult by a and coslat and 2pi
# 2. sum vertically* dp
# 3. divide by gravity

erad = con.get_earthrad() # m
grav = con.get_g() # m/s2

across=65 # across which lat circle

latidx=cutl.find_nearest(lat,across)
latrad = np.deg2rad(lat[latidx])

totlam=2*np.pi # @@@ ?
dp = np.diff(lev)

print dp.shape
print dp

print latrad
print np.cos(latrad)
print totlam

fdict={'MPEF': basepath + 'kt131f_meridional_potential_energy_flux_2921-2931_ts.nc',
       'MSHF': basepath + 'kt131f_meridional_sens_heat_flux_2921-2931_ts.nc',
       'MLHF': basepath + 'kt131f_meridional_latent_heat_flux_2921-2931_ts.nc',
       'MFZM': basepath + 'kt131f_meridional_flux_zonal_mom_2921-2931_ts.nc'}
flddt={'MPEF': 'MLT',
       'MSHF': 'MLT',
       'MLHF': 'MLT',
       'MFZM': 'MLT'}
condt={'MPEF': 1,
       'MSHF': Cp,
       'MLHF': Lv,
       'MFZM': 0.5}

fldintdt={}
for field in fdict:
    
    ncfield=flddt[field]
    
    fname=fdict[field]
    conv=condt[field] 

    fld=cnc.getNCvar(fname,ncfield,timesel='2922-01-01,2931-12-31')*conv

    fldint=np.zeros(len(lat))
    latidx=0
    for ll in lat: # do all lats
        latrad = np.deg2rad(ll)

        fldsub = np.squeeze(fld[:,:,latidx,:-1]) # get just one lat and remove extra lon
        fldtm = np.mean(cutl.seasonalize_monthlyts(fldsub,**seasonalizedt),axis=0)
    
        tmpfld = np.sum(fldtm,axis=1)*erad*np.cos(latrad)*totlam # zonal integration
    
        fldzint= (tmpfld[0:-1] + tmpfld[1:]) / 2 # interp in b/w levels
    
        fldpint = np.sum(fldzint*dp) # vertically integrate
        fldpint = fldpint/grav
        fldint[latidx] = fldpint
        latidx += 1
    
    fldintdt[field] = fldint

    print fldintdt[field]
# Out:
# (21,)
# [   100.    100.    200.    200.    300.   1000.   1000.   2000.   2000.
#    3000.   5000.   5000.   5000.   5000.  10000.  10000.  10000.  10000.
#   15000.   7500.   7500.]
# 1.14454515612
# 0.41346032366
# 6.28318530718
# [  1.78927784e+14   3.69356965e+14  -2.41276141e+15  -4.79335263e+15
#   -6.08689030e+15  -7.88462383e+15  -9.57623157e+15  -1.56762601e+16
#   -3.10390516e+16  -5.00651578e+16  -7.35369715e+16  -1.04566504e+17
#   -1.45010725e+17  -1.93218681e+17  -2.43212253e+17  -2.90071792e+17
#   -3.26737988e+17  -3.41031649e+17  -3.29176286e+17  -3.00467189e+17
#   -2.64266908e+17  -2.36822570e+17  -1.85143926e+17  -1.36931789e+17
#   -9.20031897e+16  -7.14609167e+16  -8.45666923e+16  -1.62204691e+17
#   -2.55748620e+17  -3.58673019e+17  -4.50733366e+17  -5.22832484e+17
#   -5.54412717e+17  -6.28575761e+17  -6.79680592e+17  -6.09560008e+17
#   -4.72810199e+17  -3.30245711e+17  -1.73175961e+17  -2.66774158e+16
#    9.48567271e+16   1.82029272e+17   2.41587937e+17   2.88772103e+17
#    3.17545526e+17   3.26245400e+17   3.17696294e+17   2.82597054e+17
#    2.37688582e+17   1.98041972e+17   1.52849104e+17   1.17961721e+17
#    9.13997012e+16   7.13481552e+16   5.19694748e+16   3.56492020e+16
#    2.32872869e+16   1.51192029e+16   1.09736411e+16   7.88436219e+15
#    5.66292679e+15   2.89100967e+15   1.11029754e+15   1.41480047e+14]
# [  3.36668672e+15  -1.25083493e+16  -2.78662282e+16  -3.44761194e+16
#   -2.96890661e+16  -2.17239475e+16  -2.47909635e+16  -7.55449159e+16
#   -8.41935110e+16  -4.21756609e+16   5.85199735e+15   7.00976594e+16
#    1.67623604e+17   2.82246225e+17   4.01751423e+17   4.97997604e+17
#    5.34422436e+17   4.75577039e+17   3.35437393e+17   1.36720463e+17
#   -7.77810928e+16  -2.81166687e+17  -4.63900196e+17  -6.14947980e+17
#   -6.77684660e+17  -5.92570253e+17  -3.38475404e+17   1.12498019e+17
#    7.26090442e+17   1.43888551e+18   2.00580030e+18   2.28080217e+18
#    2.32282540e+18   2.54695644e+18   2.93434168e+18   3.00006369e+18
#    2.78130978e+18   2.41664080e+18   2.00004475e+18   1.51750938e+18
#    1.04798835e+18   5.72455349e+17   1.96631394e+17  -4.57624998e+16
#   -2.31040555e+17  -3.51365861e+17  -4.50624364e+17  -4.61627431e+17
#   -4.62643415e+17  -3.98719940e+17  -3.27025075e+17  -2.65637899e+17
#   -1.79400132e+17  -1.16214465e+17  -6.05327044e+16  -3.69337278e+16
#   -5.96303489e+15   7.60044120e+15   2.19426473e+16   2.45074614e+16
#    2.05868301e+16   4.55700463e+15   1.96911603e+15   8.63276604e+14]
# [  1.18702730e+13   3.03541910e+13   5.49797556e+13   1.26293363e+14
#    2.01476437e+14   3.18078874e+14   5.15582215e+14   6.88812613e+14
#    7.65923809e+14   9.31639542e+14   9.59741044e+14   6.50147528e+14
#   -3.94139342e+14  -2.83692489e+15  -6.93467275e+15  -1.20087743e+16
#   -1.65695844e+16  -1.92102867e+16  -1.92037727e+16  -1.70608524e+16
#   -1.36868727e+16  -1.00122835e+16  -6.45738441e+15  -3.48902385e+15
#   -1.40651569e+15  -2.86318268e+14   6.29980042e+13  -1.10883916e+14
#   -3.74222782e+14  -3.48596953e+14  -1.18552634e+14   2.40423812e+14
#    6.58209342e+14   1.03294319e+15   1.20448696e+15   1.89136237e+15
#    3.63446353e+15   6.66244987e+15   1.12077642e+16   1.74335230e+16
#    2.50691679e+16   3.36226995e+16   3.84126745e+16   4.03064607e+16
#    4.03232957e+16   3.56445379e+16   2.88150873e+16   2.18435794e+16
#    1.55284328e+16   1.02171491e+16   6.27692555e+15   3.59192868e+15
#    2.00040819e+15   1.06174064e+15   4.84638994e+14   1.19687293e+14
#   -3.60032211e+13  -7.61469606e+13  -5.53792247e+13  -6.30271743e+13
#   -3.23610255e+13  -1.12314880e+13   1.21874636e+13   7.34944678e+12]
# [  1.30023473e+17   7.87498343e+16  -9.76753259e+16  -3.32649111e+16
#    3.87980581e+17   9.76574231e+17   1.54354049e+18   8.97351014e+17
#    8.46704131e+16  -5.56617108e+16  -1.57945859e+17  -2.59960159e+17
#   -3.81009145e+17  -4.99400431e+17  -5.81685389e+17  -5.64722664e+17
#   -5.07283706e+17  -4.39292892e+17  -3.67076386e+17  -2.32511657e+17
#   -7.25741070e+16  -1.18075817e+17   2.72915728e+16   3.39095674e+16
#    3.74475784e+16  -4.95107593e+16  -2.02817532e+17  -5.77988111e+17
#   -8.41187300e+17  -9.06930136e+17  -9.78860460e+17  -1.20427405e+18
#   -1.42415411e+18  -1.74637251e+18  -1.92638775e+18  -1.93646368e+18
#   -1.65563810e+18  -1.44689623e+18  -1.09395750e+18  -7.32871693e+17
#   -2.97595639e+17   1.06972194e+16   5.29425490e+17   1.29063165e+18
#    1.70198412e+18   1.43366145e+18   1.24742172e+18   1.17142364e+18
#    9.49670538e+17   1.14971840e+18   9.34660264e+17   7.54089509e+17
#    5.78751165e+17   4.61336575e+17   2.88700693e+17   1.38264852e+17
#    1.76600990e+17   1.82932967e+17   2.22718928e+17   2.07920452e+17
#    2.86524458e+17   5.62557656e+16   1.30638019e+16   3.02847009e+14]

# %%
# 1 cal = 4.186J
# convert to cal / day
# J/s -> cal/day
W2calperday = (60*60*24)/4.186

#print (MSHF+MPEF+MLHF+MZMF)*W2calperday / 10e19 # want 10^19 cal/day to compare with Hartmann


for field in fldintdt.keys():
    print field + ' ' + str(fldintdt[field])
# Out:
# MLHF [  1.78927784e+14   3.69356965e+14  -2.41276141e+15  -4.79335263e+15
#   -6.08689030e+15  -7.88462383e+15  -9.57623157e+15  -1.56762601e+16
#   -3.10390516e+16  -5.00651578e+16  -7.35369715e+16  -1.04566504e+17
#   -1.45010725e+17  -1.93218681e+17  -2.43212253e+17  -2.90071792e+17
#   -3.26737988e+17  -3.41031649e+17  -3.29176286e+17  -3.00467189e+17
#   -2.64266908e+17  -2.36822570e+17  -1.85143926e+17  -1.36931789e+17
#   -9.20031897e+16  -7.14609167e+16  -8.45666923e+16  -1.62204691e+17
#   -2.55748620e+17  -3.58673019e+17  -4.50733366e+17  -5.22832484e+17
#   -5.54412717e+17  -6.28575761e+17  -6.79680592e+17  -6.09560008e+17
#   -4.72810199e+17  -3.30245711e+17  -1.73175961e+17  -2.66774158e+16
#    9.48567271e+16   1.82029272e+17   2.41587937e+17   2.88772103e+17
#    3.17545526e+17   3.26245400e+17   3.17696294e+17   2.82597054e+17
#    2.37688582e+17   1.98041972e+17   1.52849104e+17   1.17961721e+17
#    9.13997012e+16   7.13481552e+16   5.19694748e+16   3.56492020e+16
#    2.32872869e+16   1.51192029e+16   1.09736411e+16   7.88436219e+15
#    5.66292679e+15   2.89100967e+15   1.11029754e+15   1.41480047e+14]
# MPEF [  3.36668672e+15  -1.25083493e+16  -2.78662282e+16  -3.44761194e+16
#   -2.96890661e+16  -2.17239475e+16  -2.47909635e+16  -7.55449159e+16
#   -8.41935110e+16  -4.21756609e+16   5.85199735e+15   7.00976594e+16
#    1.67623604e+17   2.82246225e+17   4.01751423e+17   4.97997604e+17
#    5.34422436e+17   4.75577039e+17   3.35437393e+17   1.36720463e+17
#   -7.77810928e+16  -2.81166687e+17  -4.63900196e+17  -6.14947980e+17
#   -6.77684660e+17  -5.92570253e+17  -3.38475404e+17   1.12498019e+17
#    7.26090442e+17   1.43888551e+18   2.00580030e+18   2.28080217e+18
#    2.32282540e+18   2.54695644e+18   2.93434168e+18   3.00006369e+18
#    2.78130978e+18   2.41664080e+18   2.00004475e+18   1.51750938e+18
#    1.04798835e+18   5.72455349e+17   1.96631394e+17  -4.57624998e+16
#   -2.31040555e+17  -3.51365861e+17  -4.50624364e+17  -4.61627431e+17
#   -4.62643415e+17  -3.98719940e+17  -3.27025075e+17  -2.65637899e+17
#   -1.79400132e+17  -1.16214465e+17  -6.05327044e+16  -3.69337278e+16
#   -5.96303489e+15   7.60044120e+15   2.19426473e+16   2.45074614e+16
#    2.05868301e+16   4.55700463e+15   1.96911603e+15   8.63276604e+14]
# MFZM [  1.18702730e+13   3.03541910e+13   5.49797556e+13   1.26293363e+14
#    2.01476437e+14   3.18078874e+14   5.15582215e+14   6.88812613e+14
#    7.65923809e+14   9.31639542e+14   9.59741044e+14   6.50147528e+14
#   -3.94139342e+14  -2.83692489e+15  -6.93467275e+15  -1.20087743e+16
#   -1.65695844e+16  -1.92102867e+16  -1.92037727e+16  -1.70608524e+16
#   -1.36868727e+16  -1.00122835e+16  -6.45738441e+15  -3.48902385e+15
#   -1.40651569e+15  -2.86318268e+14   6.29980042e+13  -1.10883916e+14
#   -3.74222782e+14  -3.48596953e+14  -1.18552634e+14   2.40423812e+14
#    6.58209342e+14   1.03294319e+15   1.20448696e+15   1.89136237e+15
#    3.63446353e+15   6.66244987e+15   1.12077642e+16   1.74335230e+16
#    2.50691679e+16   3.36226995e+16   3.84126745e+16   4.03064607e+16
#    4.03232957e+16   3.56445379e+16   2.88150873e+16   2.18435794e+16
#    1.55284328e+16   1.02171491e+16   6.27692555e+15   3.59192868e+15
#    2.00040819e+15   1.06174064e+15   4.84638994e+14   1.19687293e+14
#   -3.60032211e+13  -7.61469606e+13  -5.53792247e+13  -6.30271743e+13
#   -3.23610255e+13  -1.12314880e+13   1.21874636e+13   7.34944678e+12]
# MSHF [  1.30023473e+17   7.87498343e+16  -9.76753259e+16  -3.32649111e+16
#    3.87980581e+17   9.76574231e+17   1.54354049e+18   8.97351014e+17
#    8.46704131e+16  -5.56617108e+16  -1.57945859e+17  -2.59960159e+17
#   -3.81009145e+17  -4.99400431e+17  -5.81685389e+17  -5.64722664e+17
#   -5.07283706e+17  -4.39292892e+17  -3.67076386e+17  -2.32511657e+17
#   -7.25741070e+16  -1.18075817e+17   2.72915728e+16   3.39095674e+16
#    3.74475784e+16  -4.95107593e+16  -2.02817532e+17  -5.77988111e+17
#   -8.41187300e+17  -9.06930136e+17  -9.78860460e+17  -1.20427405e+18
#   -1.42415411e+18  -1.74637251e+18  -1.92638775e+18  -1.93646368e+18
#   -1.65563810e+18  -1.44689623e+18  -1.09395750e+18  -7.32871693e+17
#   -2.97595639e+17   1.06972194e+16   5.29425490e+17   1.29063165e+18
#    1.70198412e+18   1.43366145e+18   1.24742172e+18   1.17142364e+18
#    9.49670538e+17   1.14971840e+18   9.34660264e+17   7.54089509e+17
#    5.78751165e+17   4.61336575e+17   2.88700693e+17   1.38264852e+17
#    1.76600990e+17   1.82932967e+17   2.22718928e+17   2.07920452e+17
#    2.86524458e+17   5.62557656e+16   1.30638019e+16   3.02847009e+14]

# %%
import pandas as pd

flddf = pd.DataFrame(fldintdt)



fldtot = flddf.sum(axis=1)

print fldtot.shape

#print str(fldtot / 1e15) + ' PW'
#print str(fldtot * W2calperday / 1e19) + ' 10^19 cal/day'

fig=plt.figure()
plt.plot(lat,fldtot/1e15)
plt.title('PW')
plt.axhline(y=0)
plt.xlim((-15,75))


flddf.plot(x=lat)
plt.plot(lat,fldtot,color='k')
plt.axhline(y=0,color='0.5')
plt.xlim((-15,75))
# Out:
# (64,)
# (-15, 75)

# %%
# Next, calculate PHT for each month.

# also compare with net TOA flux poleward of given lat from Kay et al 2012
# NHT = -2piRe^2 int_lat_piover2[N cos(lat) dlat] # Re is earth's radius. N is net TOA flux (W/m2)

# if these are sufficiently comparable, then can probably use this method for iga, gregory_2xco2
#    where we don't have my calculated variables
# Out:
# 315
