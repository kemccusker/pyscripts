# %%
import cccmautils as cutl
import constants as con
# %matplotlib inline


# got memory errors so set up reading in of zonal mean files.
# but need that dimension when calculating heat trans across a latitude (I think?)
# so switched to reading in just xx years instead of 100
zonal=False 

basedir='/HOME/rkm/work/DATA/CanESM2/'
casename='prei2xco2icenh' # kt131f/ts/'
basepath=basedir+casename+'/ts/'
# timeper='2921-2931'; timesel='2922-01-01,2931-12-31'
timeper = '2021-3041'; timesel='3002-01-01,3041-12-31'# timesel='2031-01-01,3041-12-31' # skip first decade

Cp=1004 # specific heat at const pressure (J/K/kg)
Lv=2.5e6 # specific heat of condensation (latent heat of vapo) at 0C(?@@) (J/kg)

ncfield='MLT'


# J = kg m2/s2   --> J/kg = m2/s2
field='meridional_sens_heat_flux'
if zonal: 
    field=field+'ZM'
    fldsuff='ZM'
else:
    fldsuff=''
    
fname=basepath + casename + '_' + field + '_'+timeper+'_ts.nc'; conv=Cp
#     meridional_sens_heat_flux: # m/s * C (mult by Cp to get (m/s)(J/kg)
#fname=basepath + 'kt131f_zonal_sens_heat_flux_2921-2931_ts.nc'; conv=Cp 
#     zonal_sens_heat_flux: # m/s * C (mult by Cp to get (m/s)(J/kg)
#fname=basepath + 'kt131f_meridional_latent_heat_flux_2921-2931_ts.nc'; conv=Lv
#     meridional_latent_heat_flux: m/s * kg/kg (mult by Lv to get (m/s)(J/kg))
#fname=basepath + 'kt131f_meridional_potential_energy_flux_2921-2931_ts.nc'; conv=1 # z is already mult by gravity
#     meridional_potential_energy_flux: m/s * (m2/s2) ---> m/s * (J/kg)
#     geopotential is the gravitational potential energy per unit mass at that elevation h
#     the field 'gz', or PHI, is geopotential height * gravity, which is geopotential. 
#     Z = PHI/g0, where Z is geopotential height and g0 is standard gravity. 
#     https://en.wikipedia.org/wiki/Geopotential_height
#fname=basepath + 'kt131f_meridional_flux_zonal_mom_2921-2931_ts.nc'; conv=0.5 # .5 for kinetic energy
#     meridional_flux_zonal_mom: m/s * (m2/s2) --> KE is 1/2 mv^2 which is kg m2/s2.
#       so what we have is KE per kg. ---> m/s * (J/kg)

#fname=basepath + 'kt131f_zonal_flux_zonal_mom_2921-2931_ts.nc'; conv=1; field='U' # @@?
#     zonal_flux_zonal_mom: m/s * (m2/s2) ---> m/s *(J/kg) #Not sure about a conversion?
#   @@@ note that zonal_flux_zonal_mom is incorrect for kt131f. the variable is actually just U*U.


print fname


cmin=-750; cmax=750 # mer SH flux not mult by Cp
#cmin=-.8e4; cmax=.8e4 # zon SH flux not mult by Cp
#cmin=-.015; cmax=0.015 # mer LH flux not mult by Lv
#cmin=-1e5; cmax=1e5 # mer potential energy flux
#cmin=-4000; cmax=4000 # mer flux zon mom not mult by 0.5

fld=cnc.getNCvar(fname,ncfield,timesel=timesel)*conv
cmin=cmin*conv; cmax=cmax*conv

lat=cnc.getNCvar(fname,'lat')
lon=cnc.getNCvar(fname,'lon')
lev=cnc.getNCvar(fname,'plev')

print fld.shape
fldtm=fld.mean(axis=0)
print fldtm.shape

if zonal:
    fldzm=fld
    fldtmzm=fldtm
else:
    fldtmzm = fldtm.mean(axis=2)
    fldzm = fld.mean(axis=3)

print fldzm.shape
print fldtmzm.shape

cplt=reload(cplt)

plt.figure()
plt.pcolor(lat,lev,fldtmzm)
ax=plt.gca()
ax.set_yscale('log')
ax.invert_yaxis()
plt.colorbar()

fig,axs=plt.subplots(1,1)
cplt.vert_plot(fldtmzm,lev,lat,axis=axs,cmin=cmin,cmax=cmax,levlim=100)
# Out:
# /HOME/rkm/work/DATA/CanESM2/prei2xco2icenh/ts/prei2xco2icenh_meridional_sens_heat_flux_2021-3041_ts.nc
# lat: squeezing data upon read all
# lon: squeezing data upon read all
# plev: squeezing data upon read all
# (480, 22, 64, 129)
# (22, 64, 129)
# (480, 22, 64)
# (22, 64)
# <matplotlib.contour.QuadContourSet instance at 0x2b707bb9a5a8>

# %%
cplt=reload(cplt)

# no clims or contour levels
plt.figure();
fig = cplt.plotvert_allseas(fldzm,lev,lat)

# %%
plt.figure();
fig=cplt.plotvert_allseas(fldzm,lev,lat,cmin=cmin,cmax=cmax,levlim=100,latlim=0,type='nh')    

print cmax
# Out:
# 753000

# %%
# calc the vertical integral of poleward energy transport across 
#    a latitude (or all?) in units of Watts
# = 1/g int_pbot_to_ptop[  int_latcircle[ E*v a coslat dlon dp]]. a is Earth's radius

domonth=True # otherwise do season
sea='ANN'
mo=1

if domonth:
    seasonalizedt={'mo':mo}
else:
    seasonalizedt={'sea':sea}


# 1. sum around lat circle. mult by a and coslat and 2pi
# 2. sum vertically* dp
# 3. divide by gravity

erad = con.get_earthrad() # m
grav = con.get_g() # m/s2

across=65 # across which lat circle

latidx=cutl.find_nearest(lat,across)
latrad = np.deg2rad(lat[latidx])

totlam=2*np.pi # @@@ ?
dp = np.diff(lev)

print dp.shape
print dp

print latrad
print np.cos(latrad)
print totlam

fdict={'MPEF': basepath + casename + '_meridional_potential_energy_flux' + fldsuff +'_' + timeper + '_ts.nc',
       'MSHF': basepath + casename + '_meridional_sens_heat_flux' + fldsuff + '_' + timeper + '_ts.nc',
       'MLHF': basepath + casename + '_meridional_latent_heat_flux' + fldsuff + '_' + timeper + '_ts.nc',
       'MFZM': basepath + casename + '_meridional_flux_zonal_mom' + fldsuff + '_' + timeper + '_ts.nc'}
flddt={'MPEF': 'MLT',
       'MSHF': 'MLT',
       'MLHF': 'MLT',
       'MFZM': 'MLT'}
condt={'MPEF': 1,
       'MSHF': Cp,
       'MLHF': Lv,
       'MFZM': 0.5} # conversion factors

fldintdt={}
for fkey in fdict:
    
    ncfield=flddt[fkey]
    
    fname=fdict[fkey]
    conv=condt[fkey] 

    fld=cnc.getNCvar(fname,ncfield,timesel=timesel)*conv

    fldint=np.zeros(len(lat))
    latidx=0
    for ll in lat: # do all lats
        latrad = np.deg2rad(ll)

        fldsub = np.squeeze(fld[:,:,latidx,:-1]) # get just one lat and remove extra lon
        fldtm = np.mean(cutl.seasonalize_monthlyts(fldsub,**seasonalizedt),axis=0) # time mean
    
        tmpfld = np.sum(fldtm,axis=1)*erad*np.cos(latrad)*totlam # zonal integration
    
        fldzint= (tmpfld[0:-1] + tmpfld[1:]) / 2 # interp in b/w levels
    
        fldpint = np.sum(fldzint*dp) # vertically integrate
        fldpint = fldpint/grav
        fldint[latidx] = fldpint
        latidx += 1
    
    fldintdt[fkey] = fldint

    print fldintdt[fkey]
# Out:
# (21,)
# [   100.    100.    200.    200.    300.   1000.   1000.   2000.   2000.
#    3000.   5000.   5000.   5000.   5000.  10000.  10000.  10000.  10000.
#   15000.   7500.   7500.]
# 1.14454515612
# 0.41346032366
# 6.28318530718
# [  2.07402972e+14   4.98712863e+14  -2.08865633e+15  -4.72632469e+15
#   -5.93268337e+15  -8.02843433e+15  -9.79463922e+15  -1.70254569e+16
#   -3.31557407e+16  -5.41883870e+16  -7.98545656e+16  -1.13349823e+17
#   -1.54730820e+17  -2.01227203e+17  -2.50318590e+17  -2.94106139e+17
#   -3.26355220e+17  -3.37854992e+17  -3.25826693e+17  -2.96460230e+17
#   -2.60175440e+17  -2.34067376e+17  -1.83734151e+17  -1.34967411e+17
#   -8.75474624e+16  -6.73214080e+16  -7.69484511e+16  -1.41015906e+17
#   -2.30907298e+17  -3.37765280e+17  -4.48219547e+17  -5.33951397e+17
#   -5.84202979e+17  -6.59488250e+17  -6.97555831e+17  -6.21601887e+17
#   -4.78925968e+17  -3.34247157e+17  -1.74979967e+17  -2.59944792e+16
#    9.81762271e+16   1.89317419e+17   2.51633530e+17   3.00987186e+17
#    3.29964039e+17   3.36162909e+17   3.23605624e+17   2.84795783e+17
#    2.37378418e+17   1.96014442e+17   1.50739987e+17   1.14916238e+17
#    8.77445248e+16   6.72124547e+16   4.78767040e+16   3.25649050e+16
#    2.16099212e+16   1.44273044e+16   1.04963465e+16   7.54832371e+15
#    5.43814908e+15   2.76688907e+15   9.88142354e+14   1.25364623e+14]
# [  4.05925878e+15  -8.04622088e+15  -1.78455100e+16  -2.22580293e+16
#   -1.56709877e+16  -9.12493860e+15  -1.78062764e+16  -7.76737736e+16
#   -7.72000274e+16  -2.19077820e+16   3.91084785e+16   1.19252847e+17
#    2.24811072e+17   3.41071312e+17   4.51936702e+17   5.26171785e+17
#    5.43504050e+17   4.75101637e+17   3.22345463e+17   1.06710772e+17
#   -1.22983181e+17  -3.26404961e+17  -5.02095853e+17  -6.36377595e+17
#   -6.94830689e+17  -6.21301093e+17  -3.94146279e+17   3.63939221e+16
#    6.50411518e+17   1.37546358e+18   1.99890638e+18   2.34608155e+18
#    2.45045108e+18   2.68280435e+18   3.01738803e+18   3.04416098e+18
#    2.79970284e+18   2.42534282e+18   2.00043749e+18   1.52663961e+18
#    1.06879226e+18   5.90627582e+17   1.84474271e+17  -7.39108440e+16
#   -2.61127945e+17  -3.81475914e+17  -4.73511185e+17  -4.82495208e+17
#   -4.73631201e+17  -4.01827491e+17  -3.22826007e+17  -2.42527778e+17
#   -1.41153790e+17  -7.07578496e+16  -1.53239515e+16  -1.94490992e+15
#    8.33190921e+15   8.27394778e+15   1.72683923e+16   1.58347991e+16
#    9.50393782e+15  -3.70177658e+15  -2.12569488e+15  -9.55444159e+13]
# [  9.37043940e+12   1.73527722e+13   2.80791282e+13   8.17687347e+13
#    1.39932819e+14   2.67833858e+14   5.23078163e+14   8.11138162e+14
#    1.04980559e+15   1.21943966e+15   1.02612042e+15   2.39871136e+14
#   -1.55110326e+15  -4.72900741e+15  -9.34335183e+15  -1.44657732e+16
#   -1.86320805e+16  -2.08137935e+16  -2.04695627e+16  -1.80224790e+16
#   -1.43619751e+16  -1.04480192e+16  -6.77196027e+15  -3.68767327e+15
#   -1.46786293e+15  -2.44628946e+14   1.16751528e+14  -1.23373754e+13
#   -2.09072808e+14  -1.53837929e+14   1.19708716e+14   5.05532780e+14
#    9.21964142e+14   1.27301908e+15   1.48060419e+15   2.19572761e+15
#    4.00976464e+15   7.21959653e+15   1.20120587e+16   1.85832862e+16
#    2.65986202e+16   3.53568278e+16   3.99434412e+16   4.11971695e+16
#    3.99780068e+16   3.41912246e+16   2.66815593e+16   1.95966767e+16
#    1.34248181e+16   8.42698141e+15   4.89064498e+15   2.65774650e+15
#    1.50641901e+15   8.75018555e+14   4.13941661e+14   1.06154488e+14
#   -8.78569928e+13  -1.59187247e+14  -8.86594129e+13   1.36768844e+13
#    5.85118600e+13   3.65478873e+13   2.14700479e+13   5.23576728e+12]
# [  1.35537885e+17   1.16856671e+17  -1.55439008e+16   4.40205682e+16
#    4.48348162e+17   1.01734305e+18   1.58651809e+18   8.96286024e+17
#    6.59468533e+16  -9.13364416e+16  -2.09973769e+17  -3.19910641e+17
#   -4.34239724e+17  -5.12831873e+17  -5.72599038e+17  -5.52214410e+17
#   -4.99477028e+17  -4.42495602e+17  -3.86127533e+17  -2.63853828e+17
#   -1.05262476e+17  -1.24570350e+17   3.57682296e+16   4.00911525e+16
#    3.21608337e+16  -7.07564489e+16  -2.46583456e+17  -5.60134060e+17
#   -8.06044997e+17  -8.81817087e+17  -9.69715473e+17  -1.15469745e+18
#   -1.43448987e+18  -1.78596981e+18  -1.96640280e+18  -1.97340097e+18
#   -1.66354865e+18  -1.42835132e+18  -1.09299418e+18  -7.33830807e+17
#   -2.90530832e+17   3.68854601e+16   4.94408168e+17   1.33798125e+18
#    1.82044321e+18   1.49312466e+18   1.28323287e+18   1.16756066e+18
#    9.40357299e+17   1.13193196e+18   9.23909945e+17   7.53797912e+17
#    5.63453357e+17   4.57101152e+17   2.89972344e+17   1.54705983e+17
#    2.02524507e+17   2.13290970e+17   2.47023294e+17   2.28984458e+17
#    2.89089926e+17   5.82490729e+16   1.84605800e+16   2.03920030e+15]

# %%
# 1 cal = 4.186J
# convert to cal / day
# J/s -> cal/day
W2calperday = (60*60*24)/4.186

#print (MSHF+MPEF+MLHF+MZMF)*W2calperday / 10e19 # want 10^19 cal/day to compare with Hartmann


for fkey in fldintdt.keys():
    print fkey + ' ' + str(fldintdt[fkey])
# Out:
# MLHF [  2.07402972e+14   4.98712863e+14  -2.08865633e+15  -4.72632469e+15
#   -5.93268337e+15  -8.02843433e+15  -9.79463922e+15  -1.70254569e+16
#   -3.31557407e+16  -5.41883870e+16  -7.98545656e+16  -1.13349823e+17
#   -1.54730820e+17  -2.01227203e+17  -2.50318590e+17  -2.94106139e+17
#   -3.26355220e+17  -3.37854992e+17  -3.25826693e+17  -2.96460230e+17
#   -2.60175440e+17  -2.34067376e+17  -1.83734151e+17  -1.34967411e+17
#   -8.75474624e+16  -6.73214080e+16  -7.69484511e+16  -1.41015906e+17
#   -2.30907298e+17  -3.37765280e+17  -4.48219547e+17  -5.33951397e+17
#   -5.84202979e+17  -6.59488250e+17  -6.97555831e+17  -6.21601887e+17
#   -4.78925968e+17  -3.34247157e+17  -1.74979967e+17  -2.59944792e+16
#    9.81762271e+16   1.89317419e+17   2.51633530e+17   3.00987186e+17
#    3.29964039e+17   3.36162909e+17   3.23605624e+17   2.84795783e+17
#    2.37378418e+17   1.96014442e+17   1.50739987e+17   1.14916238e+17
#    8.77445248e+16   6.72124547e+16   4.78767040e+16   3.25649050e+16
#    2.16099212e+16   1.44273044e+16   1.04963465e+16   7.54832371e+15
#    5.43814908e+15   2.76688907e+15   9.88142354e+14   1.25364623e+14]
# MPEF [  4.05925878e+15  -8.04622088e+15  -1.78455100e+16  -2.22580293e+16
#   -1.56709877e+16  -9.12493860e+15  -1.78062764e+16  -7.76737736e+16
#   -7.72000274e+16  -2.19077820e+16   3.91084785e+16   1.19252847e+17
#    2.24811072e+17   3.41071312e+17   4.51936702e+17   5.26171785e+17
#    5.43504050e+17   4.75101637e+17   3.22345463e+17   1.06710772e+17
#   -1.22983181e+17  -3.26404961e+17  -5.02095853e+17  -6.36377595e+17
#   -6.94830689e+17  -6.21301093e+17  -3.94146279e+17   3.63939221e+16
#    6.50411518e+17   1.37546358e+18   1.99890638e+18   2.34608155e+18
#    2.45045108e+18   2.68280435e+18   3.01738803e+18   3.04416098e+18
#    2.79970284e+18   2.42534282e+18   2.00043749e+18   1.52663961e+18
#    1.06879226e+18   5.90627582e+17   1.84474271e+17  -7.39108440e+16
#   -2.61127945e+17  -3.81475914e+17  -4.73511185e+17  -4.82495208e+17
#   -4.73631201e+17  -4.01827491e+17  -3.22826007e+17  -2.42527778e+17
#   -1.41153790e+17  -7.07578496e+16  -1.53239515e+16  -1.94490992e+15
#    8.33190921e+15   8.27394778e+15   1.72683923e+16   1.58347991e+16
#    9.50393782e+15  -3.70177658e+15  -2.12569488e+15  -9.55444159e+13]
# MFZM [  9.37043940e+12   1.73527722e+13   2.80791282e+13   8.17687347e+13
#    1.39932819e+14   2.67833858e+14   5.23078163e+14   8.11138162e+14
#    1.04980559e+15   1.21943966e+15   1.02612042e+15   2.39871136e+14
#   -1.55110326e+15  -4.72900741e+15  -9.34335183e+15  -1.44657732e+16
#   -1.86320805e+16  -2.08137935e+16  -2.04695627e+16  -1.80224790e+16
#   -1.43619751e+16  -1.04480192e+16  -6.77196027e+15  -3.68767327e+15
#   -1.46786293e+15  -2.44628946e+14   1.16751528e+14  -1.23373754e+13
#   -2.09072808e+14  -1.53837929e+14   1.19708716e+14   5.05532780e+14
#    9.21964142e+14   1.27301908e+15   1.48060419e+15   2.19572761e+15
#    4.00976464e+15   7.21959653e+15   1.20120587e+16   1.85832862e+16
#    2.65986202e+16   3.53568278e+16   3.99434412e+16   4.11971695e+16
#    3.99780068e+16   3.41912246e+16   2.66815593e+16   1.95966767e+16
#    1.34248181e+16   8.42698141e+15   4.89064498e+15   2.65774650e+15
#    1.50641901e+15   8.75018555e+14   4.13941661e+14   1.06154488e+14
#   -8.78569928e+13  -1.59187247e+14  -8.86594129e+13   1.36768844e+13
#    5.85118600e+13   3.65478873e+13   2.14700479e+13   5.23576728e+12]
# MSHF [  1.35537885e+17   1.16856671e+17  -1.55439008e+16   4.40205682e+16
#    4.48348162e+17   1.01734305e+18   1.58651809e+18   8.96286024e+17
#    6.59468533e+16  -9.13364416e+16  -2.09973769e+17  -3.19910641e+17
#   -4.34239724e+17  -5.12831873e+17  -5.72599038e+17  -5.52214410e+17
#   -4.99477028e+17  -4.42495602e+17  -3.86127533e+17  -2.63853828e+17
#   -1.05262476e+17  -1.24570350e+17   3.57682296e+16   4.00911525e+16
#    3.21608337e+16  -7.07564489e+16  -2.46583456e+17  -5.60134060e+17
#   -8.06044997e+17  -8.81817087e+17  -9.69715473e+17  -1.15469745e+18
#   -1.43448987e+18  -1.78596981e+18  -1.96640280e+18  -1.97340097e+18
#   -1.66354865e+18  -1.42835132e+18  -1.09299418e+18  -7.33830807e+17
#   -2.90530832e+17   3.68854601e+16   4.94408168e+17   1.33798125e+18
#    1.82044321e+18   1.49312466e+18   1.28323287e+18   1.16756066e+18
#    9.40357299e+17   1.13193196e+18   9.23909945e+17   7.53797912e+17
#    5.63453357e+17   4.57101152e+17   2.89972344e+17   1.54705983e+17
#    2.02524507e+17   2.13290970e+17   2.47023294e+17   2.28984458e+17
#    2.89089926e+17   5.82490729e+16   1.84605800e+16   2.03920030e+15]

# %%
import pandas as pd

flddf = pd.DataFrame(fldintdt)



fldtot = flddf.sum(axis=1)

print fldtot.shape

#print str(fldtot / 1e15) + ' PW'
#print str(fldtot * W2calperday / 1e19) + ' 10^19 cal/day'

fig=plt.figure()
plt.plot(lat,fldtot)
plt.title('Watts')
plt.axhline(y=0)
plt.xlim((-15,75))

fig=plt.figure()
plt.plot(lat,fldtot/1e15)
plt.title('PW')
plt.axhline(y=0)
plt.xlim((-15,75))

fig=plt.figure()
plt.plot(lat,fldtot*W2calperday/1e19)
plt.title('10^19 cal/day')
plt.axhline(y=0)
plt.xlim((-15,75))

flddf.plot(x=lat)
plt.plot(lat,fldtot,color='k')
plt.axhline(y=0,color='0.5')
plt.xlim((-15,75))


(flddf*W2calperday/1e19).plot(x=lat)
plt.plot(lat,fldtot*W2calperday/1e19,color='k')
plt.axhline(y=0,color='0.5')
plt.xlim((-15,75))
plt.title(str(seasonalizedt))

# Note to self: sensible heat flux doesn't seem correct,
#  based on a comparison with Hartmann Fig 6.10
# Y axis on fig of components below (in cal/day) are about 2 O too big
#   Also, total flux in (PW) are 3 O too big based on Hartmann Fig 6.11?
# Out:
# (64,)

# %%
# Next, calculate PHT for each month.

# also compare with net TOA flux poleward of given lat from Kay et al 2012
# NHT = -2piRe^2 int_lat_piover2[N cos(lat) dlat] # Re is earth's radius. N is net TOA flux (W/m2)

# if these are sufficiently comparable, then can probably use this method for iga, gregory_2xco2
#    where we don't have my calculated variables

print 1e19 == 10**19
# Out:
# True
